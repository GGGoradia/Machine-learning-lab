# %% [markdown]
# # Mean Median (Weighted and Trimmed)

# %%
#Mean Median and trimmed mean
import pandas as pd
from scipy.stats import trim_mean
state=pd.read_csv("state_data.csv")
mean=state['Population'].mean()
median=state['Population'].median()
tmean=trim_mean(state['Population'],0.1)
print(tmean)
# Out:
# 7694135.625

# %%
#weighted median and mean
import numpy as np
import wquantiles
wmean=np.average(state['Murder rate'], weights=state['Population'])
wmedian=wquantiles.median(state['Murder rate'],weights=state['Population'])
print(wmean,wmedian)
# Out:
# 4.376359279149048 4.448750497554494
